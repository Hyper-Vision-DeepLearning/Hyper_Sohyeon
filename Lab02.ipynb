# %% [markdown]
# # Lab 2: Linear Regression

# %% [markdown]
# Author: Seungjae Lee (이승재)

# %% [markdown]
# <div class="alert alert-warning">
#     We use elemental PyTorch to implement linear regression here. However, in most actual applications, abstractions such as <code>nn.Module</code> or <code>nn.Linear</code> are used.
# </div>

# %% [markdown]
# ## Theoretical Overview

# %% [markdown]
# $$ H(x) = Wx + b $$

# %% [markdown]
# $$ cost(W, b) = \frac{1}{m} \sum^m_{i=1} \left( H(x^{(i)}) - y^{(i)} \right)^2 $$

# %% [markdown]
#  - $H(x)$: 주어진 $x$ 값에 대해 예측을 어떻게 할 것인가
#  - $cost(W, b)$: $H(x)$ 가 $y$ 를 얼마나 잘 예측했는가

# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# For reproducibility
torch.manual_seed(1)

# %% [markdown]
# ## Data

# %% [markdown]
# We will use fake data for this example.

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[1], [2], [3]])

# %%
print(x_train)
print(x_train.shape)
# Out:
# tensor([[1.],
#         [2.],
#         [3.]])
# torch.Size([3, 1])

# %%
print(y_train)
print(y_train.shape)
# Out:
# tensor([[1.],
#         [2.],
#         [3.]])
# torch.Size([3, 1])

# %% [markdown]
# 기본적으로 PyTorch는 NCHW 형태이다.

# %% [markdown]
# ## Weight Initialization

# %%
W = torch.zeros(1, requires_grad=True)
print(W)
# Out:
# tensor([0.], requires_grad=True)

# %%
b = torch.zeros(1, requires_grad=True)
print(b)
# Out:
# tensor([0.], requires_grad=True)

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# $$ H(x) = Wx + b $$

# %%
hypothesis = x_train * W + b
print(hypothesis)
# Out:
# tensor([[0.],
#         [0.],
#         [0.]], grad_fn=<AddBackward0>)

# %% [markdown]
# ## Cost

# %% [markdown]
# $$ cost(W, b) = \frac{1}{m} \sum^m_{i=1} \left( H(x^{(i)}) - y^{(i)} \right)^2 $$

# %%
print(hypothesis)
# Out:
# tensor([[0.],
#         [0.],
#         [0.]], grad_fn=<AddBackward0>)

# %%
print(y_train)
# Out:
# tensor([[1.],
#         [2.],
#         [3.]])

# %%
print(hypothesis - y_train)
# Out:
# tensor([[-1.],
#         [-2.],
#         [-3.]], grad_fn=<SubBackward0>)

# %%
print((hypothesis - y_train) ** 2)
# Out:
# tensor([[1.],
#         [4.],
#         [9.]], grad_fn=<PowBackward0>)

# %%
cost = torch.mean((hypothesis - y_train) ** 2)
print(cost)
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %% [markdown]
# ## Gradient Descent

# %%
optimizer = optim.SGD([W, b], lr=0.01)

# %%
optimizer.zero_grad()
cost.backward()
optimizer.step()

# %%
print(W)
print(b)
# Out:
# tensor([0.0933], requires_grad=True)
# tensor([0.0400], requires_grad=True)

# %% [markdown]
# Let's check if the hypothesis is now better.

# %%
hypothesis = x_train * W + b
print(hypothesis)
# Out:
# tensor([[0.1333],
#         [0.2267],
#         [0.3200]], grad_fn=<AddBackward0>)

# %%
cost = torch.mean((hypothesis - y_train) ** 2)
print(cost)
# Out:
# tensor(3.6927, grad_fn=<MeanBackward0>)

# %% [markdown]
# ## Training with Full Code

# %% [markdown]
# In reality, we will be training on the dataset for multiple epochs. This can be done simply with loops.

# %% [markdown]
# 위의 내용을 참고해 전체 코드를 완성시키세요.

# %%
# 데이터
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[1], [2], [3]])
# 모델 초기화
W =torch.zeros(1, requires_grad=True)
#이 부분을 채워넣으세요.# #가중치 W를 0으로 초기화하고 학습을 통해 값이 변경될 수 있도록 하세요.
b =  torch.zeros(1, requires_grad=True)
#이 부분을 채워넣으세요.# #편향 b를 0으로 초기화하고 학습을 통해 값이 변경될 수 있도록 하세요.
# optimizer 설정
optimizer = optim.SGD([W, b], lr=0.01)
#이 부분을 채워넣으세요.# #SGD optimizer를 사용하고 learning rate는 0.01로 적용하세요.

nb_epochs = 1000
for epoch in range(nb_epochs + 1):
    
    # H(x) 계산
    hypothesis = x_train * W + b
    #이 부분을 채워넣으세요.# H(x)=Wx+b를 이용하세요.
    
    # cost 계산
    cost = torch.mean((hypothesis - y_train) ** 2)
    #이 부분을 채워넣으세요.# #파이토치 코드 상으로 선형 회귀의 비용 함수에 해당되는 평균 제곱 오차를 선언하세요.

    # cost로 H(x) 개선
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    #이 부분을 채워넣으세요.#  # gradient를 0으로 초기화
    #이 부분을 채워넣으세요.#  # 비용 함수를 미분하여 gradient 계산
    #이 부분을 채워넣으세요.#  # W와 b를 업데이트

    # 100번마다 로그 출력
    if epoch % 100 == 0:
        print('Epoch {:4d}/{} W: {:.3f}, b: {:.3f} Cost: {:.6f}'.format(
            epoch, nb_epochs, W.item(), b.item(), cost.item()
        ))
# Out:
# Epoch    0/1000 W: 0.093, b: 0.040 Cost: 4.666667
# Epoch  100/1000 W: 0.873, b: 0.289 Cost: 0.012043
# Epoch  200/1000 W: 0.900, b: 0.227 Cost: 0.007442
# Epoch  300/1000 W: 0.921, b: 0.179 Cost: 0.004598
# Epoch  400/1000 W: 0.938, b: 0.140 Cost: 0.002842
# Epoch  500/1000 W: 0.951, b: 0.110 Cost: 0.001756
# Epoch  600/1000 W: 0.962, b: 0.087 Cost: 0.001085
# Epoch  700/1000 W: 0.970, b: 0.068 Cost: 0.000670
# Epoch  800/1000 W: 0.976, b: 0.054 Cost: 0.000414
# Epoch  900/1000 W: 0.981, b: 0.042 Cost: 0.000256
# Epoch 1000/1000 W: 0.985, b: 0.033 Cost: 0.000158

# %% [markdown]
# ## High-level Implementation with `nn.Module`

# %% [markdown]
# Remember that we had this fake data.

# %%
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[1], [2], [3]])

# %% [markdown]
# 이제 linear regression 모델을 만들면 되는데, 기본적으로 PyTorch의 모든 모델은 제공되는 `nn.Module`을 inherit 해서 만들게 됩니다.

# %%
class LinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)

    def forward(self, x):
        return self.linear(x)

# %% [markdown]
# 모델의 `__init__`에서는 사용할 레이어들을 정의하게 됩니다. 여기서 우리는 linear regression 모델을 만들기 때문에, `nn.Linear` 를 이용할 것입니다. 그리고 `forward`에서는 이 모델이 어떻게 입력값에서 출력값을 계산하는지 알려줍니다.

# %%
model = LinearRegressionModel()

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# 이제 모델을 생성해서 예측값 $H(x)$를 구해보자

# %%
hypothesis = model(x_train)

# %%
print(hypothesis)
# Out:
# tensor([[0.0739],
#         [0.5891],
#         [1.1044]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## Cost

# %% [markdown]
# 이제 mean squared error (MSE) 로 cost를 구해보자. MSE 역시 PyTorch에서 기본적으로 제공한다.

# %%
print(hypothesis)
print(y_train)
# Out:
# tensor([[0.0739],
#         [0.5891],
#         [1.1044]], grad_fn=<AddmmBackward0>)
# tensor([[1.],
#         [2.],
#         [3.]])

# %%
cost = F.mse_loss(hypothesis, y_train)

# %%
print(cost)
# Out:
# tensor(2.1471, grad_fn=<MseLossBackward0>)

# %% [markdown]
# ## Gradient Descent

# %% [markdown]
# 마지막 주어진 cost를 이용해 $H(x)$ 의 $W, b$ 를 바꾸어서 cost를 줄여봅니다. 이때 PyTorch의 `torch.optim` 에 있는 `optimizer` 들 중 하나를 사용할 수 있습니다.

# %%
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
optimizer.zero_grad()
cost.backward()
optimizer.step()

# %% [markdown]
# ## Training with Full Code

# %% [markdown]
# 이제 Linear Regression 코드를 이해했으니, 실제로 코드를 돌려 피팅시켜보겠습니다.

# %% [markdown]
# 위의 내용을 참고해 전체 코드를 완성시키세요.

# %%
# 데이터
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[1], [2], [3]])
# 모델 초기화
model = LinearRegressionModel()
#이 부분을 채워넣으세요.# #LinearRegressionModel()로 모델을 초기화하세요.
# optimizer 설정
optimizer = optimizer = optim.SGD(model.parameters(), lr=0.01)
#이 부분을 채워넣으세요.# #SGD optimizer를 사용하고 learning rate는 0.01로 적용하세요.

nb_epochs = 1000
for epoch in range(nb_epochs + 1):


    # H(x) 계산
    prediction = model(x_train)
    #이 부분을 채워넣으세요. #모델을 생성해서 예측값을 구해보세요.
    
    # cost 계산
    cost = torch.mean((prediction - y_train) ** 2)
    #이 부분을 채워넣으세요.# #파이토치 코드 상으로 선형 회귀의 비용 함수에 해당되는 평균 제곱 오차를 선언하세요.

 
    cost = F.mse_loss(prediction, y_train)
    #이 부분을 채워넣으세요.# #PyTorch에서 기본적으로 제공하는 mse 함수를 사용하세요.
    
    # cost로 H(x) 개선
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    #이 부분을 채워넣으세요.#  # gradient를 0으로 초기화
    #이 부분을 채워넣으세요.#  # 비용 함수를 미분하여 gradient 계산
    #이 부분을 채워넣으세요.#  # W와 b를 업데이트
    
    # 100번마다 로그 출력
    if epoch % 100 == 0:
        params = list(model.parameters())
        W = params[0].item()
        b = params[1].item()
        print('Epoch {:4d}/{} W: {:.3f}, b: {:.3f} Cost: {:.6f}'.format(
            epoch, nb_epochs, W, b, cost.item()
        ))
# Out:
# Epoch    0/1000 W: 0.343, b: 0.077 Cost: 2.296805
# Epoch  100/1000 W: 0.894, b: 0.241 Cost: 0.008392
# Epoch  200/1000 W: 0.917, b: 0.190 Cost: 0.005186
# Epoch  300/1000 W: 0.934, b: 0.149 Cost: 0.003204
# Epoch  400/1000 W: 0.948, b: 0.117 Cost: 0.001980
# Epoch  500/1000 W: 0.959, b: 0.092 Cost: 0.001224
# Epoch  600/1000 W: 0.968, b: 0.072 Cost: 0.000756
# Epoch  700/1000 W: 0.975, b: 0.057 Cost: 0.000467
# Epoch  800/1000 W: 0.980, b: 0.045 Cost: 0.000289
# Epoch  900/1000 W: 0.985, b: 0.035 Cost: 0.000178
# Epoch 1000/1000 W: 0.988, b: 0.028 Cost: 0.000110

# %% [markdown]
# 점점 $H(x)$ 의 $W$ 와 $b$ 를 조정해서 cost가 줄어드는 것을 볼 수 있습니다.
